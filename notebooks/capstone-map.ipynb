# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\sulli\anaconda3\lib\site-packages (0.14.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: fiona>=1.8.21 in c:\users\sulli\anaconda3\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\sulli\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\sulli\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\sulli\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\sulli\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sulli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\sulli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in c:\users\sulli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\sulli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\sulli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\sulli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\sulli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sulli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sulli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sulli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sulli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.24.3)
# Requirement already satisfied: colorama in c:\users\sulli\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\sulli\anaconda3\lib\site-packages (0.15.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\sulli\anaconda3\lib\site-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sulli\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\sulli\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\sulli\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\sulli\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sulli\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sulli\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sulli\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sulli\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sulli\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
zipcodes = gpd.read_file('./data/LakeCounty_Health_5114257871172773279.geojson')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# EPSG:3435
#    OBJECTID          County  Percent_1  \
# 0         1  McHenry County       27.7
# 1         2    Boone County       33.7
# 2         3     Ogle County       31.2
# 3         4     Will County       28.0
# 4         5  LaSalle County       27.1
#
#                                             geometry
# 0  POLYGON ((883358.271 2122657.886, 888572.603 2...
# 1  POLYGON ((883358.271 2122657.886, 883362.596 2...
# 2  POLYGON ((617161.942 2018203.086, 622481.577 2...
# 3  POLYGON ((1003871.064 1842165.938, 1003869.036...
# 4  POLYGON ((818708.973 1807747.960, 818747.663 1...

302969, 952152.811399614 1998647.28465557, 946661.123720204 1998544.58589773, 941384.347264847 1998524.49298369, 939033.078461953 1998587.56399309, 939033.492620622 1998619.19437071, 937447.152632049 1998630.21888166, 936115.864856398 1998640.96555868, 936101.819167092 1998641.14060614, 936081.725858643 1998640.89105737, 936067.680168767 1998641.06579781, 936049.076990645 1998640.30290534, 936029.010824723 1998640.08972349, 930850.520728295 1998652.54914069, 930822.916195137 1998652.39391137, 930780.752238431 1998652.96515398, 930730.044711668 1998652.60843701, 925577.147055613 1998664.32980961, 925555.563465141 1998664.60344569, 925542.004505058 1998664.27339473, 925520.936186617 1998664.54542862, 925507.865430305 1998664.21415911, 925494.821741861 1998663.88282828, 921660.645344594 1998663.03581236, 920301.101426464 1998662.63363293, 920289.035119802 1998662.7761018, 920274.98951496 1998662.96075234, 920258.420859226 1998662.67849099, 920246.354553633 1998662.82130982, 920232.308949 1998663.00598626, 920206.70983357 1998662.34792519, 915083.058265171 1998683.35735941, 915037.369619351 1998683.96781019, 911777.379062369 1998670.69405668, 911167.366691733 1998668.09309316, 909837.846159558 1998662.85390016, 909814.771222582 1 ...

# %%
zipcodes.loc(-95.8304,29.7404)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\sulli\OneDrive\capstone\district-data\capstone-map.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sulli/OneDrive/capstone/district-data/capstone-map.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> zipcodes.loc(-95.8304,29.7404)
#
# TypeError: _LocationIndexer.__call__() takes from 1 to 2 positional arguments but 3 were given

# %%
zipcodes.plot();

# %%
leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left', 
            'bbox_to_anchor': (1, 1.03), 'ncol': 2}

zipcodes.plot(column = 'County', figsize=(10, 10),
              edgecolor = 'black',
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set2')
plt.show()

# %%
zipcodes = gpd.read_file('./data/school-zones.json')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Failed to read ESRIJSON data
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# c:\Users\sulli\OneDrive\capstone\district-data\capstone-map.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sulli/OneDrive/capstone/district-data/capstone-map.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> zipcodes = gpd.read_file('./data/school-zones.json')
#       <a href='vscode-notebook-cell:/c%3A/Users/sulli/OneDrive/capstone/district-data/capstone-map.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> print(zipcodes.crs)
#       <a href='vscode-notebook-cell:/c%3A/Users/sulli/OneDrive/capstone/district-data/capstone-map.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> zipcodes.head( )
#
# File c:\Users\sulli\anaconda3\Lib\site-packages\geopandas\io\file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
#     298         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     299     )
#     301 else:
#     302     raise ValueError(f"unknown engine '{engine}'")
#
# File c:\Users\sulli\anaconda3\Lib\site-packages\geopandas\io\file.py:338, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     335     reader = fiona.open
#     337 with fiona_env():
# --> 338     with reader(path_or_bytes, **kwargs) as features:
#     339         crs = features.crs_wkt
#     340         # attempt to get EPSG code
#
# File c:\Users\sulli\anaconda3\Lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File c:\Users\sulli\anaconda3\Lib\site-packages\fiona\__init__.py:305, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     302     path = parse_path(fp)
#     304 if mode in ("a", "r"):
# --> 305     colxn = Collection(
#     306         path,
#     307         mode,
#     308         driver=driver,
#     309         encoding=encoding,
#     310         layer=layer,
#     311         enabled_drivers=enabled_drivers,
#     312         allow_unsupported_drivers=allow_unsupported_drivers,
#     313         **kwargs
#     314     )
#     315 elif mode == "w":
#     316     colxn = Collection(
#     317         path,
#     318         mode,
#    (...)
#     327         **kwargs
#     328     )
#
# File c:\Users\sulli\anaconda3\Lib\site-packages\fiona\collection.py:243, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     241 if self.mode == "r":
#     242     self.session = Session()
# --> 243     self.session.start(self, **kwargs)
#     244 elif self.mode in ("a", "w"):
#     245     self.session = WritingSession()
#
# File fiona\\ogrext.pyx:588, in fiona.ogrext.Session.start()
#
# File fiona\\ogrext.pyx:143, in fiona.ogrext.gdal_open_vector()
#
# DriverError: Failed to read ESRIJSON data

# %%
spots = pd.read_csv('./data/extra-activities.csv')
print(spots.shape)
spots.head(3)
# Out:
# (61, 6)
#                            name       type  \
# 0           Math Logic Tutoring       math
# 1    Mathnasium of Morton Ranch       math
# 2  The Tutoring Center, Katy TX  elar/math
#
#                                 address  Zip_Code       lat       lon
# 0    5323 Castle Discordia St, Katy, TX     77493  29.85059 -95.81509
# 1  22720 Morton Ranch Rd #140, Katy, TX     77449  29.81808 -95.76568
# 2    2001 Katy Mills Blvd # F, Katy, TX     77494  29.78339 -95.80607

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
spots_geo = gpd.GeoDataFrame(spots, 
                           crs = zipcodes.crs, 
                           geometry = gpd.points_from_xy(spots.lon, spots.lat))
